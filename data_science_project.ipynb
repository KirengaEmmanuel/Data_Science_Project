# %% [markdown]
# <a href="https://colab.research.google.com/github/KirengaEmmanuel/Data_Science_Project/blob/main/data_science_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ingest

# %%
import pandas as pd

# %% [markdown]
# ##EDA

# %% [markdown]
# ##MODEL

# %% [markdown]
# ##CONCLUSION
